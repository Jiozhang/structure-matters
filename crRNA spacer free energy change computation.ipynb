# %%
# Compute ensemble free enegy changes for crRNAs with AsCas12a direct repeats for the original 29 targets

import RNA   # ViennaRNA package 
import math

file1 = open('crRNA sequence array-29 original-As.txt', 'r')    # Input crRNA sequences with AsCas12a direct repeat

sequence_array = file1.readlines()
index = 0

for sequence in sequence_array:
    print("crRNA sequence: " + str(sequence).strip())

    # Set global switch for unique ML decomposition
    RNA.cvar.uniq_ML = 1
    
    # create new fold_compound object
    fc = RNA.fold_compound(sequence)
    
    # compute minimum free energy (mfe) and corresponding structure
    (ss, mfe) = fc.mfe()
    
    # Compute MFE structure and ensemble free energy of the entire crRNA including the direct repeat
    (bp_propensity, dG) = fc.pf() 
    
    # Compute only the ensemble free energy change of the spacer
    dG_change = dG + 4.80       # -4.80 kcal/mol is the MFE of crRNA with a linear spacer
    print("dG: " + str(dG_change) + " kcal/mol")
    
    # Compute MFE frequency using Boltzmann equilibrium probability distribution 
    kT = RNA.exp_param().kT / 1000.
    prob_mfe = math.exp((dG - mfe) / kT)
    print("MFE frequency: " + str(prob_mfe))

    # print MFE and corresponding structure
    print("MFE structure: " + str("{} [ {:6.2f} ]".format(ss, mfe)))
    print()
    index += 1
# Out:
# crRNA sequence: UAAUUUCUACUCUUGUAGAUAGUAUAUCAAUAGAUAUACU
# dG: -7.598914337158203 kcal/mol
# MFE frequency: 0.7241583981782784
# MFE structure: .....(((((....))))).((((((((....)))))))). [ -12.20 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCAUGAACUGUAGUUUAUGG
# dG: -7.913929176330567 kcal/mol
# MFE frequency: 0.8312263969892058
# MFE structure: .....(((((....))))).((((((((....)))))))). [ -12.60 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUGGGAUCGCUUACGUGAUCCC
# dG: -13.098048400878906 kcal/mol
# MFE frequency: 0.8529214033727736
# MFE structure: .....(((((....))))).((((((((....)))))))). [ -17.80 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCGUGGGCUGCCGUCCACGG
# dG: -13.70661277770996 kcal/mol
# MFE frequency: 0.8411517198613355
# MFE structure: .....(((((....))))).((((((((....)))))))). [ -18.40 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUGAAUUUCAUUUGAAAUUCC
# dG: -5.418503952026367 kcal/mol
# MFE frequency: 0.8250792797201003
# MFE structure: .....(((((....)))))..(((((((....))))))).. [ -10.10 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUGAGUAGUGAUGACUACUCU
# dG: -9.519743156433105 kcal/mol
# MFE frequency: 0.8234212375307671
# MFE structure: .....(((((....)))))..(((((((....))))))).. [ -14.20 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCGUAGGGCACUUGUCCUGCA
# dG: -10.397305679321288 kcal/mol
# MFE frequency: 0.8539514550320377
# MFE structure: .....(((((....)))))..(((((((....))))))).. [ -15.10 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUGGUCGGGCAGCUGCCCGACG
# dG: -14.631636810302734 kcal/mol
# MFE frequency: 0.8076825862575308
# MFE structure: .....(((((....)))))..(((((((....))))))).. [ -19.30 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCAGAUUUCAAAUGAAAUCAA
# dG: -5.2040407180786135 kcal/mol
# MFE frequency: 0.8446693897997677
# MFE structure: .....(((((....)))))...((((((....))))))... [  -9.90 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCGUUACUGAUAAGUGACUC
# dG: -6.213669967651367 kcal/mol
# MFE frequency: 0.8315750335730744
# MFE structure: .....(((((....)))))...((((((....))))))... [ -10.90 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCGUCAAGUUGCCUUGGCCA
# dG: -5.7125999450683596 kcal/mol
# MFE frequency: 0.8330200228752129
# MFE structure: .....(((((....)))))...((((((....))))))... [ -10.40 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCGGCUCGGCCACGAGCCUC
# dG: -11.993210983276366 kcal/mol
# MFE frequency: 0.8596443361225081
# MFE structure: .....(((((....)))))...((((((....))))))... [ -16.70 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCUCAUUCUAUUGAAUGUUU
# dG: -3.8270217895507814 kcal/mol
# MFE frequency: 0.8137542351071713
# MFE structure: .....(((((....)))))....(((((....))))).... [  -8.50 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCAAGUUAGUAUUCUAGCCCU
# dG: -3.6261436462402346 kcal/mol
# MFE frequency: 0.8149147632320528
# MFE structure: .....(((((....)))))....(((((....))))).... [  -8.30 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCAAGCGACAGAGGUCGCAAC
# dG: -7.810054016113281 kcal/mol
# MFE frequency: 0.8364687388363475
# MFE structure: .....(((((....)))))....(((((....))))).... [ -12.50 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCCGUGCCUGCAGGCGCUCG
# dG: -7.516295623779297 kcal/mol
# MFE frequency: 0.8280401408756644
# MFE structure: .....(((((....)))))....(((((....))))).... [ -12.20 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCAAAGUACUAUAGUACAAUA
# dG: -2.7379605293273928 kcal/mol
# MFE frequency: 0.7994388951760993
# MFE structure: .....(((((....))))).....((((....))))..... [  -7.40 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCACGUAGUAUUCUGCCAAU
# dG: -2.8339731216430666 kcal/mol
# MFE frequency: 0.8046276639913308
# MFE structure: .....(((((....))))).....((((....))))..... [  -7.50 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCCAGCCUGGCGAGGCAUAA
# dG: -6.32515926361084 kcal/mol
# MFE frequency: 0.8162171259844971
# MFE structure: .....(((((....))))).....((((....))))..... [ -11.00 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCCAGGGCCACGGUCCACGC
# dG: -5.220022392272949 kcal/mol
# MFE frequency: 0.8230480006791134
# MFE structure: .....(((((....))))).....((((....))))..... [  -9.90 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCAAAGACUAAUGUCAAAUU
# dG: -2.7345630645751955 kcal/mol
# MFE frequency: 0.8038579663783165
# MFE structure: .....(((((....)))))......(((....)))...... [  -7.40 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCGACCGUCUUAUGACAAUAU
# dG: -2.7280933380126955 kcal/mol
# MFE frequency: 0.8123407795124614
# MFE structure: .....(((((....)))))......(((....)))...... [  -7.40 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCCUCGGCAACCGCCAUCAU
# dG: -4.213472557067871 kcal/mol
# MFE frequency: 0.8318414338192377
# MFE structure: .....(((((....)))))......(((....)))...... [  -8.90 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCCACGGCACCUGCCACGCG
# dG: -4.228453826904297 kcal/mol
# MFE frequency: 0.8118651484101397
# MFE structure: .....(((((....)))))......(((....)))...... [  -8.90 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCAAACUUUAUCAUCAUUAU
# dG: -0.12475318908691424 kcal/mol
# MFE frequency: 0.8167553359412192
# MFE structure: .....(((((....)))))...................... [  -4.80 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUUCCAAAUCCAAUAACAAUAU
# dG: -0.13155479431152362 kcal/mol
# MFE frequency: 0.807791324543804
# MFE structure: .....(((((....)))))...................... [  -4.80 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCUCACCAUUUCCAUUUACU
# dG: -0.1002876281738283 kcal/mol
# MFE frequency: 0.8498294921679262
# MFE structure: .....(((((....)))))...................... [  -4.80 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCCAGCUAAUCCCAUCCCAG
# dG: -0.11387033462524432 kcal/mol
# MFE frequency: 0.8313055027999655
# MFE structure: .....(((((....)))))...................... [  -4.80 ]
#
# crRNA sequence: UAAUUUCUACUCUUGUAGAUCCCGACCCAGCCUGCUCCCG
# dG: -0.20876712799072283 kcal/mol
# MFE frequency: 0.7126741503980791
# MFE structure: .....(((((....)))))..................... [  -4.80 ]

# %%
# Compute ensemble free enegy changes for crRNAs with LbCas12a direct repeats for the original 29 targets

import RNA   # ViennaRNA package 
import math

file1 = open('crRNA sequence array-29 original-Lb.txt', 'r')    # Input crRNA sequences with LbCas12a direct repeat

sequence_array = file1.readlines()
index = 0

for sequence in sequence_array:
    print("crRNA sequence: " + str(sequence).strip())
    # Set global switch for unique ML decomposition
    RNA.cvar.uniq_ML = 1

    # create new fold_compound object
    fc = RNA.fold_compound(sequence)

    # compute minimum free energy (mfe) and corresponding structure
    (ss, mfe) = fc.mfe()
    
    # Compute MFE structure and ensemble free energy of the entire crRNA including the direct repeat
    (bp_propensity, dG) = fc.pf() 
    
    # Compute only the ensemble free energy change of the spacer
    dG_change = dG + 4.70       # -4.70 kcal/mol is the MFE of crRNA with a linear spacer
    print("dG: " + str(dG_change) + " kcal/mol")
    
    # Compute MFE frequency using Boltzmann equilibrium probability distribution 
    kT = RNA.exp_param().kT / 1000.
    prob_mfe = math.exp((dG - mfe) / kT)
    print("MFE frequency: " + str(prob_mfe))

    # print MFE and corresponding structure
    print("MFE structure: " + str("{} [ {:6.2f} ]".format(ss, mfe)))
    print()
    index += 1
# Out:
# crRNA sequence: UAAUUUCUACUAAGUGUAGA
]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCAAAGUACUAUAGUACAAUA
# dG: -2.7415469169616697 kcal/mol
# MFE frequency: 0.7948005698429682
# MFE structure: .....(((((.....))))).....((((....))))..... [  -7.30 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUUCACGUAGUAUUCUGCCAAU
# dG: -2.982168960571289 kcal/mol
# MFE frequency: 0.6326563276666634
# MFE structure: .....(((((.....))))).....((((....))))..... [  -7.40 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUUCCAGCCUGGCGAGGCAUAA
# dG: -6.325029182434082 kcal/mol
# MFE frequency: 0.8163889103314181
# MFE structure: .....(((((.....))))).....((((....))))..... [ -10.90 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCCCAGGGCCACGGUCCACGC
# dG: -5.221706199645996 kcal/mol
# MFE frequency: 0.8208032390156541
# MFE structure: .....(((((.....))))).....((((....))))..... [  -9.80 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUUCAAAGACUAAUGUCAAAUU
# dG: -2.7343156814575194 kcal/mol
# MFE frequency: 0.8041808136777706
# MFE structure: .....(((((.....)))))......(((....)))...... [  -7.30 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCGACCGUCUUAUGACAAUAU
# dG: -2.72779541015625 kcal/mol
# MFE frequency: 0.8127336836139915
# MFE structure: .....(((((.....)))))......(((....)))...... [  -7.30 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUUCCUCGGCAACCGCCAUCAU
# dG: -4.213434028625488 kcal/mol
# MFE frequency: 0.831894209210396
# MFE structure: .....(((((.....)))))......(((....)))...... [  -8.80 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCCCACGGCACCUGCCACGCG
# dG: -4.230044174194336 kcal/mol
# MFE frequency: 0.8097736729408525
# MFE structure: .....(((((.....)))))......(((....)))...... [  -8.80 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUUCAAACUUUAUCAUCAUUAU
# dG: -0.1285927772521971 kcal/mol
# MFE frequency: 0.8116823841456783
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUUCCAAAUCCAAUAACAAUAU
# dG: -0.13124732971191388 kcal/mol
# MFE frequency: 0.8081939085655407
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCCUCACCAUUUCCAUUUACU
# dG: -0.12618045806884748 kcal/mol
# MFE frequency: 0.814865586805443
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCCCAGCUAAUCCCAUCCCAG
# dG: -0.11401348114013654 kcal/mol
# MFE frequency: 0.8311119319903987
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCCCGACCCAGCCUGCUCCCG
# dG: -0.2124703407287596 kcal/mol
# MFE frequency: 0.7084043913476668
# MFE structure: .....(((((.....)))))..................... [  -4.70 ]

# %%
# Compute ensemble free enegy changes for crRNAs with LbCas12a direct repeats for the additional 32 targets

import RNA   # ViennaRNA package 
import math

file1 = open('crRNA sequence array-32 viral fragments-Lb.txt', 'r')    # Input crRNA sequences with LbCas12a direct repeat

sequence_array = file1.readlines()
index = 0

for sequence in sequence_array:
    print("crRNA sequence: " + str(sequence).strip())
    # Set global switch for unique ML decomposition
    RNA.cvar.uniq_ML = 1

    # create new fold_compound object
    fc = RNA.fold_compound(sequence)

    # compute minimum free energy (mfe) and corresponding structure
    (ss, mfe) = fc.mfe()
    
    # Compute MFE structure and ensemble free energy of the entire crRNA including the direct repeat
    (bp_propensity, dG) = fc.pf() 
    
    # Compute only the ensemble free energy change of the spacer
    dG_change = dG + 4.70       # -4.70 kcal/mol is the MFE of crRNA with a linear spacer
    print("dG: " + str(dG_change) + " kcal/mol")
    
    # Compute MFE frequency using Boltzmann equilibrium probability distribution 
    kT = RNA.exp_param().kT / 1000.
    prob_mfe = math.exp((dG - mfe) / kT)
    print("MFE frequency: " + str(prob_mfe))

    # print MFE and corresponding structure
    print("MFE structure: " + str("{} [ {:6.2f} ]".format(ss, mfe)))
    print()
    index += 1
# Out:
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUAACAATTGGCGCGCCTCTTT
# dG: -0.8267324447631834 kcal/mol
# MFE frequency: 0.26147936351624473
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCACGAGGACGAGGACAAGGA
# dG: -0.903569984436035 kcal/mol
# MFE frequency: 0.23083057968678286
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUAGCATTATCAGAAGGAGCCA
# dG: -0.9312594413757322 kcal/mol
# MFE frequency: 0.2206895578414265
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUGTAGTGCTATCCCCATGTGA
# dG: -0.8257382392883299 kcal/mol
# MFE frequency: 0.2619015040896729
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUAATATGTCTCTCAGCCTTTT
# dG: -0.4945652961730955 kcal/mol
# MFE frequency: 0.44823026970010466
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCATGTGGGCTCTTATAATCT
# dG: -0.5453351020812987 kcal/mol
# MFE frequency: 0.41278689843700916
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUTTTTTTATTTTCATATATAA
# dG: -0.7952898025512694 kcal/mol
# MFE frequency: 0.27516531115365983
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUTATAGTGAATAGAGTTAGGC
# dG: -0.6238987922668455 kcal/mol
# MFE frequency: 0.3633837349671997
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUAACGGGTTTGCGGTGTAAGT
# dG: -1.9187610626220701 kcal/mol
# MFE frequency: 0.16280122566528077
# MFE structure: .....(((((.....)))))...((......))......... [  -5.50 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUAAAGCGAAGACAGCGGGTAT
# dG: -1.4920719146728514 kcal/mol
# MFE frequency: 0.5293270461039588
# MFE structure: .....(((((.....)))))....((.......))....... [  -5.80 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUTGAACAGGCAGAGCTAGAGA
# dG: -1.4302280426025389 kcal/mol
# MFE frequency: 0.26000068488890793
# MFE structure: .....(((((.....))))).......(((...)))...... [  -5.30 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCAACCATCTGTAGGTCCCAA
# dG: -1.5091894149780272 kcal/mol
# MFE frequency: 0.6055189169757391
# MFE structure: .....(((((.....)))))...(((.......)))...... [  -5.90 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUTTCCTAAGAAACGTAAACGT
# dG: -1.1791894912719725 kcal/mol
# MFE frequency: 0.24014489079675247
# MFE structure: .....(((((.....)))))...........(((....))). [  -5.00 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUCTATTAAGTGTTTGCCTAGG
# dG: -1.1722910881042479 kcal/mol
# MFE frequency: 0.14925787416357567
# MFE structure: .....(((((.....)))))...................... [  -4.70 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGAUAAGTTTTATTCTAAAATTAG
# dG: -1.3805711746215819 kcal/mol
# MFE frequency: 0.281815924548195
# MFE structure: .....(((((.....)))))..(((((((...)))))))... [  -5.30 ]
#
# crRNA sequence: UAAUUUCUACUAAGUGUAGA