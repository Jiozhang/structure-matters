# %%
# Compute free energy change of 29 original dsDNA activator

from nupack import *   # Import NUACK package

# Obtain the reverse complement of a DNA strand to assemble the double strand
def DNA_reverse_complement(DNA):
    complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
    return ''.join(complement.get(base, base) for base in reversed(DNA))

my_model = Model(material='DNA', ensemble='stacking', celsius=37, sodium=0.1, magnesium=0.01)   # Define NUPACK model, ion concentration in consistent with NEBuffer r3.1

sequence_array = ['AGTATATCTATTGATATACT', 'CCATAAACTACAGTTCATGG', 'GGGATCACGTAAGCGATCCC', 'CCGTGGACGGCAGCCCACGG', 'GGAATTTCAAATGAAATTCA', 'AGAGTAGTCATCACTACTCA', 'TGCAGGACAAGTGCCCTACG', 'CGTCGGGCAGCTGCCCGACC', 'TTGATTTCATTTGAAATCTG', 'GAGTCACTTATCAGTAACGA', 'TGGCCAAGGCAACTTGACGG', 'GAGGCTCGTGGCCGAGCCGG', 'AAACATTCAATAGAATGAGA', 'AGGGCTAGAATACTAACTTG', 'GTTGCGACCTCTGTCGCTTG', 'CGAGCGCCTGCAGGCACGGG', 'TATTGTACTATAGTACTTTG', 'ATTGGCAGAATACTACGTGA', 'TTATGCCTCGCCAGGCTGGA', 'GCGTGGACCGTGGCCCTGGG', 'AATTTGACATTAGTCTTTGA', 'ATATTGTCATAAGACGGTCG', 'ATGATGGCGGTTGCCGAGGA', 'CGCGTGGCAGGTGCCGTGGG', 'ATAATGATGATAAAGTTTGA', 'ATATTGTTATTGGATTTGGA', 'AGTAAATGGAAATGGTGAGG', 'CTGGGATGGGATTAGCTGGG', 'CGGGAGCAGGCTGGGTCGGG']

for sequence in sequence_array:
    print("dsDNA forward sequence: " + str(sequence))
    anti_sequence = DNA_reverse_complement(sequence)
    print("dsDNA reverse sequence: " + str(anti_sequence))
    
    # Compute free enegy change under the defined perfect hybridization structure
    dGstruc = structure_energy(strands=[sequence, anti_sequence], structure='((((((((((((((((((((+))))))))))))))))))))', model=my_model)
    print("dG: " + str(dGstruc) + ' kcal/mol')
    print()
# Out:
# dsDNA forward sequence: AGTATATCTATTGATATACT
# dsDNA reverse sequence: AGTATATCAATAGATATACT
# dG: -17.557099658807928 kcal/mol
#
# dsDNA forward sequence: CCATAAACTACAGTTCATGG
# dsDNA reverse sequence: CCATGAACTGTAGTTTATGG
# dG: -22.167099658807935 kcal/mol
#
# dsDNA forward sequence: GGGATCACGTAAGCGATCCC
# dsDNA reverse sequence: GGGATCGCTTACGTGATCCC
# dG: -26.67709965880794 kcal/mol
#
# dsDNA forward sequence: CCGTGGACGGCAGCCCACGG
# dsDNA reverse sequence: CCGTGGGCTGCCGTCCACGG
# dG: -31.867099658807934 kcal/mol
#
# dsDNA forward sequence: GGAATTTCAAATGAAATTCA
# dsDNA reverse sequence: TGAATTTCATTTGAAATTCC
# dG: -20.56709965880793 kcal/mol
#
# dsDNA forward sequence: AGAGTAGTCATCACTACTCA
# dsDNA reverse sequence: TGAGTAGTGATGACTACTCT
# dG: -22.23709965880793 kcal/mol
#
# dsDNA forward sequence: TGCAGGACAAGTGCCCTACG
# dsDNA reverse sequence: CGTAGGGCACTTGTCCTGCA
# dG: -27.547099658807934 kcal/mol
#
# dsDNA forward sequence: CGTCGGGCAGCTGCCCGACC
# dsDNA reverse sequence: GGTCGGGCAGCTGCCCGACG
# dG: -31.957099658807937 kcal/mol
#
# dsDNA forward sequence: TTGATTTCATTTGAAATCTG
# dsDNA reverse sequence: CAGATTTCAAATGAAATCAA
# dG: -20.457099658807927 kcal/mol
#
# dsDNA forward sequence: GAGTCACTTATCAGTAACGA
# dsDNA reverse sequence: TCGTTACTGATAAGTGACTC
# dG: -22.447099658807932 kcal/mol
#
# dsDNA forward sequence: TGGCCAAGGCAACTTGACGG
# dsDNA reverse sequence: CCGTCAAGTTGCCTTGGCCA
# dG: -28.087099658807933 kcal/mol
#
# dsDNA forward sequence: GAGGCTCGTGGCCGAGCCGG
# dsDNA reverse sequence: CCGGCTCGGCCACGAGCCTC
# dG: -31.64709965880793 kcal/mol
#
# dsDNA forward sequence: AAACATTCAATAGAATGAGA
# dsDNA reverse sequence: TCTCATTCTATTGAATGTTT
# dG: -20.257099658807935 kcal/mol
#
# dsDNA forward sequence: AGGGCTAGAATACTAACTTG
# dsDNA reverse sequence: CAAGTTAGTATTCTAGCCCT
# dG: -22.107099658807932 kcal/mol
#
# dsDNA forward sequence: GTTGCGACCTCTGTCGCTTG
# dsDNA reverse sequence: CAAGCGACAGAGGTCGCAAC
# dG: -27.657099658807933 kcal/mol
#
# dsDNA forward sequence: CGAGCGCCTGCAGGCACGGG
# dsDNA reverse sequence: CCCGTGCCTGCAGGCGCTCG
# dG: -32.347099658807934 kcal/mol
#
# dsDNA forward sequence: TATTGTACTATAGTACTTTG
# dsDNA reverse sequence: CAAAGTACTATAGTACAATA
# dG: -18.697099658807936 kcal/mol
#
# dsDNA forward sequence: ATTGGCAGAATACTACGTGA
# dsDNA reverse sequence: TCACGTAGTATTCTGCCAAT
# dG: -23.48709965880793 kcal/mol
#
# dsDNA forward sequence: TTATGCCTCGCCAGGCTGGA
# dsDNA reverse sequence: TCCAGCCTGGCGAGGCATAA
# dG: -27.98709965880793 kcal/mol
#
# dsDNA forward sequence: GCGTGGACCGTGGCCCTGGG
# dsDNA reverse sequence: CCCAGGGCCACGGTCCACGC
# dG: -31.537099658807936 kcal/mol
#
# dsDNA forward sequence: AATTTGACATTAGTCTTTGA
# dsDNA reverse sequence: TCAAAGACTAATGTCAAATT
# dG: -20.517099658807933 kcal/mol
#
# dsDNA forward sequence: ATATTGTCATAAGACGGTCG
# dsDNA reverse sequence: CGACCGTCTTATGACAATAT
# dG: -22.917099658807935 kcal/mol
#
# dsDNA forward sequence: ATGATGGCGGTTGCCGAGGA
# dsDNA reverse sequence: TCCTCGGCAACCGCCATCAT
# dG: -28.397099658807935 kcal/mol
#
# dsDNA forward sequence: CGCGTGGCAGGTGCCGTGGG
# dsDNA reverse sequence: CCCACGGCACCTGCCACGCG
# dG: -32.41709965880793 kcal/mol
#
# dsDNA forward sequence: ATAATGATGATAAAGTTTGA
# dsDNA reverse sequence: TCAAACTTTATCATCATTAT
# dG: -19.13709965880793 kcal/mol
#
# dsDNA forward sequence: ATATTGTTATTGGATTTGGA
# dsDNA reverse sequence: TCCAAATCCAATAACAATAT
# dG: -20.23709965880793 kcal/mol
#
# dsDNA forward sequence: AGTAAATGGAAATGGTGAGG
# dsDNA reverse sequence: CCTCACCATTTCCATTTACT
# dG: -22.787099658807932 kcal/mol
#
# dsDNA forward sequence: CTGGGATGGGATTAGCTGGG
# dsDNA reverse sequence: CCCAGCTAATCCCATCCCAG
# dG: -25.997099658807933 kcal/mol
#
# dsDNA forward sequence: CGGGAGCAGGCTGGGTCGGG
# dsDNA reverse sequence: CCCGACCCAGCCTGCTCCCG
# dG: -31.067099658807933 kcal/mol

# %%
# Compute free energy change of 32 additional dsDNA activator

from nupack import *   # Import NUACK package

# Obtain the reverse complement of a DNA strand to assemble the double strand
def DNA_reverse_complement(DNA):
    complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
    return ''.join(complement.get(base, base) for base in reversed(DNA))

my_model = Model(material='DNA', ensemble='stacking', celsius=37, sodium=0.1, magnesium=0.01)   # Define NUPACK model, ion concentration in consistent with NEBuffer r3.1

sequence_array = ['AAAGAGGCGCGCCAATTGTT', 'TCCTTGTCCTCGTCCTCGTG', 'TGGCTCCTTCTGATAATGCT', 'TCACATGGGGATAGCACTAC', 'AAAAGGCTGAGAGACATATT', 'AGATTATAAGAGCCCACATG', 'TTATATATGAAAATAAAAAA', 'GCCTAACTCTATTCACTATA', 'ACTTACACCGCAAACCCGTT', 'ATACCCGCTGTCTTCGCTTT', 'TCTCTAGCTCTGCCTGTTCA', 'TTGGGACCTACAGATGGTTG', 'ACGTTTACGTTTCTTAGGAA', 'CCTAGGCAAACACTTAATAG', 'CTAATTTTAGAATAAAACTT', 'TGTATCCTATGATTTCACTT', 'TCCTGGGGGAGGTTGTAGAC', 'CATTGGCCGTGACAGCTTGA', 'GGTGGCGTTAAAAACTTCAC', 'CTGTGCAGTTAACATCCTGA', 'GAAAAACCTAGCTGTAAAGG', 'ATACTCTGCAAGAAGTAGAC', 'TAGCTTAAGTAAAAACAAAC', 'CCATACATAATAAAATGATG', 'ACGCTGGCTAAACCATGTGT', 'CGCGTACGCGCAAACAGTCT', 'CGGCCTGATAGATTTCAGTT', 'AGCAGCATTACCATCCTGAG', 'AAAGCACCGTCTATGCAATA', 'ATAGGTGGTTTGCAACCAAT', 'CATAACTCATTGAATCATAA', 'GTTGAAAAGTAGATCTTCAA']

for sequence in sequence_array:
    print("dsDNA forward sequence: " + str(sequence))
    anti_sequence = DNA_reverse_complement(sequence)
    print("dsDNA reverse sequence: " + str(anti_sequence))
    
    # Compute free enegy change under the defined perfect hybridization structure
    dGstruc = structure_energy(strands=[sequence, anti_sequence], structure='((((((((((((((((((((+))))))))))))))))))))', model=my_model)
    print("dG: " + str(dGstruc) + ' kcal/mol')
    print()
# Out:
# dsDNA forward sequence: AAAGAGGCGCGCCAATTGTT
# dsDNA reverse sequence: AACAATTGGCGCGCCTCTTT
# dG: -27.307099658807935 kcal/mol
#
# dsDNA forward sequence: TCCTTGTCCTCGTCCTCGTG
# dsDNA reverse sequence: CACGAGGACGAGGACAAGGA
# dG: -26.95709965880793 kcal/mol
#
# dsDNA forward sequence: TGGCTCCTTCTGATAATGCT
# dsDNA reverse sequence: AGCATTATCAGAAGGAGCCA
# dG: -24.357099658807936 kcal/mol
#
# dsDNA forward sequence: TCACATGGGGATAGCACTAC
# dsDNA reverse sequence: GTAGTGCTATCCCCATGTGA
# dG: -24.49709965880793 kcal/mol
#
# dsDNA forward sequence: AAAAGGCTGAGAGACATATT
# dsDNA reverse sequence: AATATGTCTCTCAGCCTTTT
# dG: -22.267099658807936 kcal/mol
#
# dsDNA forward sequence: AGATTATAAGAGCCCACATG
# dsDNA reverse sequence: CATGTGGGCTCTTATAATCT
# dG: -22.487099658807935 kcal/mol
#
# dsDNA forward sequence: TTATATATGAAAATAAAAAA
# dsDNA reverse sequence: TTTTTTATTTTCATATATAA
# dG: -16.077099658807928 kcal/mol
#
# dsDNA forward sequence: GCCTAACTCTATTCACTATA
# dsDNA reverse sequence: TATAGTGAATAGAGTTAGGC
# dG: -20.74709965880793 kcal/mol
#
# dsDNA forward sequence: ACTTACACCGCAAACCCGTT
# dsDNA reverse sequence: AACGGGTTTGCGGTGTAAGT
# dG: -26.547099658807934 kcal/mol
#
# dsDNA forward sequence: ATACCCGCTGTCTTCGCTTT
# dsDNA reverse sequence: AAAGCGAAGACAGCGGGTAT
# dG: -26.217099658807935 kcal/mol
#
# dsDNA forward sequence: TCTCTAGCTCTGCCTGTTCA
# dsDNA reverse sequence: TGAACAGGCAGAGCTAGAGA
# dG: -25.05709965880793 kcal/mol
#
# dsDNA forward sequence: TTGGGACCTACAGATGGTTG
# dsDNA reverse sequence: CAACCATCTGTAGGTCCCAA
# dG: -24.637099658807937 kcal/mol
#
# dsDNA forward sequence: ACGTTTACGTTTCTTAGGAA
# dsDNA reverse sequence: TTCCTAAGAAACGTAAACGT
# dG: -22.747099658807933 kcal/mol
#
# dsDNA forward sequence: CCTAGGCAAACACTTAATAG
# dsDNA reverse sequence: CTATTAAGTGTTTGCCTAGG
# dG: -22.027099658807934 kcal/mol
#
# dsDNA forward sequence: CTAATTTTAGAATAAAACTT
# dsDNA reverse sequence: AAGTTTTATTCTAAAATTAG
# dG: -17.61709965880793 kcal/mol
#
# dsDNA forward sequence: TGTATCCTATGATTTCACTT
# dsDNA reverse sequence: AAGTGAAATCATAGGATACA
# dG: -20.81709965880793 kcal/mol
#
# dsDNA forward sequence: TCCTGGGGGAGGTTGTAGAC
# dsDNA reverse sequence: GTCTACAACCTCCCCCAGGA
# dG: -26.117099658807934 kcal/mol
#
# dsDNA forward sequence: CATTGGCCGTGACAGCTTGA
# dsDNA reverse sequence: TCAAGCTGTCACGGCCAATG
# dG: -27.03709965880793 kcal/mol
#
# dsDNA forward sequence: GGTGGCGTTAAAAACTTCAC
# dsDNA reverse sequence: GTGAAGTTTTTAACGCCACC
# dG: -24.49709965880793 kcal/mol
#
# dsDNA forward sequence: CTGTGCAGTTAACATCCTGA
# dsDNA reverse sequence: TCAGGATGTTAACTGCACAG
# dG: -24.087099658807933 kcal/mol
#
# dsDNA forward sequence: GAAAAACCTAGCTGTAAAGG
# dsDNA reverse sequence: CCTTTACAGCTAGGTTTTTC
# dG: -22.417099658807935 kcal/mol
#
# dsDNA forward sequence: ATACTCTGCAAGAAGTAGAC
# dsDNA reverse sequence: GTCTACTTCTTGCAGAGTAT
# dG: -22.337099658807926 kcal/mol
#
# dsDNA forward sequence: TAGCTTAAGTAAAAACAAAC
# dsDNA reverse sequence: GTTTGTTTTTACTTAAGCTA
# dG: -20.127099658807932 kcal/mol
#
# dsDNA forward sequence: CCATACATAATAAAATGATG
# dsDNA reverse sequence: CATCATTTTATTATGTATGG
# dG: -19.107099658807932 kcal/mol
#
# dsDNA forward sequence: ACGCTGGCTAAACCATGTGT
# dsDNA reverse sequence: ACACATGGTTTAGCCAGCGT
# dG: -26.39709965880793 kcal/mol
#
# dsDNA forward sequence: CGCGTACGCGCAAACAGTCT
# dsDNA reverse sequence: AGACTGTTTGCGCGTACGCG
# dG: -29.03709965880793 kcal/mol
#
# dsDNA forward sequence: CGGCCTGATAGATTTCAGTT
# dsDNA reverse sequence: AACTGAAATCTATCAGGCCG
# dG: -24.047099658807934 kcal/mol
#
# dsDNA forward sequence: AGCAGCATTACCATCCTGAG
# dsDNA reverse sequence: CTCAGGATGGTAATGCTGCT
# dG: -24.997099658807933 kcal/mol
#
# dsDNA forward sequence: AAAGCACCGTCTATGCAATA
# dsDNA reverse sequence: TATTGCATAGACGGTGCTTT
# dG: -23.98709965880793 kcal/mol
#
# dsDNA forward sequence: ATAGGTGGTTTGCAACCAAT
# dsDNA reverse sequence: ATTGGTTGCAAACCACCTAT
# dG: -23.98709965880793 kcal/mol
#
# dsDNA forward sequence: CATAACTCATTGAATCATAA
# dsDNA reverse sequence: TTATGATTCAATGAGTTATG
# dG: -19.63709965880793 kcal/mol
#
# dsDNA forward sequence: GTTGAAAAGTAGATCTTCAA
# dsDNA reverse sequence: TTGAAGATCTACTTTTCAAC
# dG: -20.817099658807933 kcal/mol
